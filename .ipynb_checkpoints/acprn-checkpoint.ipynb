# %%
import os
from PIL import Image
import pillow_heif  # Library for HEIC to PNG conversion

# Function to delete all PNG files in a given folder
def delete_all_png_files(folder):
    for filename in os.listdir(folder):
        if filename.lower().endswith('.png'):
            file_path = os.path.join(folder, filename)
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

# Function to convert HEIC to PNG
def convert_heic_to_png(heic_path, output_path):
    heif_file = pillow_heif.read_heif(heic_path)
    image = Image.frombytes(
        heif_file.mode, heif_file.size, heif_file.data, "raw", heif_file.mode, heif_file.stride
    )
    image.save(output_path, "PNG")
    print(f"Converted HEIC to PNG: {output_path}")

# Function to clean folder of PNGs and convert HEIC files to PNG
def process_folder(folder):
    # Step 1: Delete all PNG files
    delete_all_png_files(folder)
    
    # Step 2: Convert HEIC files to PNG
    for filename in os.listdir(folder):
        if filename.lower().endswith('.heic'):
            heic_path = os.path.join(folder, filename)
            png_filename = filename.replace('.HEIC', '.png').replace('.heic', '.png')
            png_path = os.path.join(folder, png_filename)
            try:
                convert_heic_to_png(heic_path, png_path)
            except Exception as e:
                print(f"Error converting {heic_path}: {e}")

# Paths to your train and test directories
train_path = './train/'
test_path = './test/'

# Process both train and test folders
process_folder(train_path)
process_folder(test_path)
# Out:
# Converted HEIC to PNG: ./train/IMG_2404.png
# Converted HEIC to PNG: ./train/IMG_2405.png
# Converted HEIC to PNG: ./train/IMG_2406.png
# Converted HEIC to PNG: ./train/IMG_2407.png
# Converted HEIC to PNG: ./train/IMG_2408.png
# Converted HEIC to PNG: ./train/IMG_2409.png
# Converted HEIC to PNG: ./train/IMG_2410.png
# Converted HEIC to PNG: ./train/IMG_2411.png
# Converted HEIC to PNG: ./train/IMG_2412.png
# Converted HEIC to PNG: ./train/IMG_2413.png
# Converted HEIC to PNG: ./train/IMG_2415.png
# Converted HEIC to PNG: ./train/IMG_2416.png
# Converted HEIC to PNG: ./train/IMG_2417.png
# Converted HEIC to PNG: ./train/IMG_2418.png
# Converted HEIC to PNG: ./train/IMG_2419.png
# Converted HEIC to PNG: ./train/IMG_2420.png
# Converted HEIC to PNG: ./train/IMG_2421.png
# Converted HEIC to PNG: ./train/IMG_2422.png
# Converted HEIC to PNG: ./train/IMG_2423.png
# Converted HEIC to PNG: ./train/IMG_2424.png
# Converted HEIC to PNG: ./train/IMG_2426.png
# Converted HEIC to PNG: ./train/IMG_2427.png
# Converted HEIC to PNG: ./train/IMG_2430.png
# Converted HEIC to PNG: ./train/IMG_2434.png
# Converted HEIC to PNG: ./train/IMG_2435.png
# Converted HEIC to PNG: ./train/IMG_2436.png
# Converted HEIC to PNG: ./train/IMG_2437.png
# Converted HEIC to PNG: ./train/IMG_2438.png
# Converted HEIC to PNG: ./train/IMG_2440.png
# Converted HEIC to PNG: ./train/IMG_2442.png
# Converted HEIC to PNG: ./train/IMG_2443.png
# Converted HEIC to PNG: ./train/IMG_2445.png
# Converted HEIC to PNG: ./train/IMG_2446 2.png
# Converted HEIC to PNG: ./train/IMG_2448.png
# Converted HEIC to PNG: ./train/IMG_2449.png
# Converted HEIC to PNG: ./train/IMG_2450.png
# Converted HEIC to PNG: ./train/IMG_2451.png
# Converted HEIC to PNG: ./train/IMG_2452.png
# Converted HEIC to PNG: ./train/IMG_2453.png
# Converted HEIC to PNG: ./train/IMG_2454.png
# Converted HEIC to PNG: ./train/IMG_2455.png
# Converted HEIC to PNG: ./train/IMG_2456.png
# Converted HEIC to PNG: ./train/IMG_2457.png
# Converted HEIC to PNG: ./train/IMG_2458.png
# Converted HEIC to PNG: ./train/IMG_2459.png
# Converted HEIC to PNG: ./train/IMG_2461.png
# Converted HEIC to PNG: ./train/IMG_2462.png
# Converted HEIC to PNG: ./train/IMG_2465.png
# Converted HEIC to PNG: ./train/IMG_2466.png
# Converted HEIC to PNG: ./train/IMG_2467.png
# Converted HEIC to PNG: ./train/IMG_2468.png
# Converted HEIC to PNG: ./train/IMG_2469.png
# Converted HEIC to PNG: ./train/IMG_2470.png
# Converted HEIC to PNG: ./train/IMG_2471.png
# Converted HEIC to PNG: ./train/IMG_2473.png
# Converted HEIC to PNG: ./train/IMG_2474.png
# Converted HEIC to PNG: ./train/IMG_2476.png
# Converted HEIC to PNG: ./train/IMG_2477.png
# Converted HEIC to PNG: ./train/IMG_2478.png
# Converted HEIC to PNG: ./train/IMG_2479.png
# Converted HEIC to PNG: ./train/IMG_2480.png
# Converted HEIC to PNG: ./train/IMG_2481.png
# Converted HEIC to PNG: ./train/IMG_2482.png
# Converted HEIC to PNG: ./train/IMG_2483.png
# Converted HEIC to PNG: ./train/IMG_2484.png
# Converted HEIC to PNG: ./train/IMG_2485.png
# Converted HEIC to PNG: ./train/IMG_2486.png
# Converted HEIC to PNG: ./train/IMG_2487.png
# Converted HEIC to PNG: ./train/IMG_2489.png
# Converted HEIC to PNG: ./train/IMG_2492.png
# Converted HEIC to PNG: ./train/IMG_2493.png
# Converted HEIC to PNG: ./train/IMG_2494.png
# Converted HEIC to PNG: ./train/IMG_2495.png
# Converted HEIC to PNG: ./train/IMG_2496.png
# Converted HEIC to PNG: ./train/IMG_2497.png
# Converted HEIC to PNG: ./train/IMG_2498.png
# Converted HEIC to PNG: ./train/IMG_2500.png
# Converted HEIC to PNG: ./train/IMG_2501.png
# Converted HEIC to PNG: ./train/IMG_2502.png
# Converted HEIC to PNG: ./train/IMG_2503.png
# Converted HEIC to PNG: ./train/IMG_2504.png
# Converted HEIC to PNG: ./train/IMG_2505.png
# Converted HEIC to PNG: ./train/IMG_2507.png
# Converted HEIC to PNG: ./train/IMG_2509.png
# Converted HEIC to PNG: ./train/IMG_2512.png
# Converted HEIC to PNG: ./train/IMG_2513.png
# Converted HEIC to PNG: ./train/IMG_2514.png
# Converted HEIC to PNG: ./train/IMG_2515.png
# Converted HEIC to PNG: ./train/IMG_2517.png
# Converted HEIC to PNG: ./train/IMG_2518.png
# Converted HEIC to PNG: ./train/IMG_2519.png
# Converted HEIC to PNG: ./train/IMG_2520.png
# Converted HEIC to PNG: ./train/IMG_2522.png
# Converted HEIC to PNG: ./train/IMG_2523.png
# Converted HEIC to PNG: ./train/IMG_2524.png
# Converted HEIC to PNG: ./train/IMG_2525.png
# Converted HEIC to PNG: ./train/IMG_2526.png
# Converted HEIC to PNG: ./train/IMG_2527.png
# Converted HEIC to PNG: ./train/IMG_2528.png
# Converted HEIC to PNG: ./train/IMG_2529.png
# Converted HEIC to PNG: ./train/IMG_2530.png
# Converted HEIC to PNG: ./train/IMG_2531.png
# Converted HEIC to PNG: ./train/IMG_2532.png
# Converted HEIC to PNG: ./train/IMG_2533.png
# Converted HEIC to PNG: ./train/IMG_2534.png
# Converted HEIC to PNG: ./train/IMG_2535.png
# Converted HEIC to PNG: ./train/IMG_2536.png
# Converted HEIC to PNG: ./train/IMG_2537.png
# Converted HEIC to PNG: ./train/IMG_2538.png
# Converted HEIC to PNG: ./train/IMG_2540.png
# Converted HEIC to PNG: ./train/IMG_2542.png
# Converted HEIC to PNG: ./train/IMG_2543.png
# Converted HEIC to PNG: ./train/IMG_2544.png
# Converted HEIC to PNG: ./train/IMG_2545.png
# Converted HEIC to PNG: ./train/IMG_2546.png
# Converted HEIC to PNG: ./train/IMG_2547.png
# Converted HEIC to PNG: ./train/IMG_2550.png
# Converted HEIC to PNG: ./train/IMG_2568.png
# Converted HEIC to PNG: ./train/IMG_2571.png
# Converted HEIC to PNG: ./train/IMG_2573.png
# Converted HEIC to PNG: ./test/IMG_2414.png
# Converted HEIC to PNG: ./test/IMG_2425.png
# Converted HEIC to PNG: ./test/IMG_2428.png
# Converted HEIC to PNG: ./test/IMG_2429.png
# Converted HEIC to PNG: ./test/IMG_2431.png
# Converted HEIC to PNG: ./test/IMG_2432.png
# Converted HEIC to PNG: ./test/IMG_2433.png
# Converted HEIC to PNG: ./test/IMG_2439.png
# Converted HEIC to PNG: ./test/IMG_2441.png
# Converted HEIC to PNG: ./test/IMG_2444.png
# Converted HEIC to PNG: ./test/IMG_2447.png
# Converted HEIC to PNG: ./test/IMG_2460.png
# Converted HEIC to PNG: ./test/IMG_2464.png
# Converted HEIC to PNG: ./test/IMG_2472.png
# Converted HEIC to PNG: ./test/IMG_2475.png
# Converted HEIC to PNG: ./test/IMG_2488.png
# Converted HEIC to PNG: ./test/IMG_2490.png
# Converted HEIC to PNG: ./test/IMG_2491.png
# Converted HEIC to PNG: ./test/IMG_2499.png
# Converted HEIC to PNG: ./test/IMG_2506.png
# Converted HEIC to PNG: ./test/IMG_2508.png
# Converted HEIC to PNG: ./test/IMG_2510.png
# Converted HEIC to PNG: ./test/IMG_2511.png
# Converted HEIC to PNG: ./test/IMG_2516.png
# Converted HEIC to PNG: ./test/IMG_2521.png
# Converted HEIC to PNG: ./test/IMG_2539.png
# Converted HEIC to PNG: ./test/IMG_2541.png
# Converted HEIC to PNG: ./test/IMG_2548.png
# Converted HEIC to PNG: ./test/IMG_2549.png
# Converted HEIC to PNG: ./test/IMG_2569.png
# Converted HEIC to PNG: ./test/IMG_2570.png
# Converted HEIC to PNG: ./test/IMG_2572.png

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img, img_to_array

# Function to load and show images
def load_and_show_data(folder, num_images=5):
    images = []
    labels = []
    filenames = []
    
    # Load images from folder
    for filename in os.listdir(folder):
        if filename.lower().endswith('.png'):
            img = load_img(os.path.join(folder, filename), color_mode='grayscale', target_size=(100, 100))
            images.append(img_to_array(img).flatten())
            label = filename.split('_')[0]  # Extract label from filename
            labels.append(label)
            filenames.append(filename)
            if len(images) >= num_images:  # Limit number of images loaded for display
                break
    
    # Convert to numpy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    # Show the images with their labels
    plt.figure(figsize=(10, 5))
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.imshow(images[i].reshape(100, 100), cmap='gray')
        plt.title(f"Label: {labels[i]}")
        plt.axis('off')
    
    plt.show()

    return np.array(images), np.array(labels), filenames

# Paths to your train and test folders
train_path = './train/'
test_path = './test/'

# Load and show data from the train folder
print("Training Data:")
train_images, train_labels, train_filenames = load_and_show_data(train_path, num_images=5)

# Load and show data from the test folder
print("Testing Data:")
test_images, test_labels, test_filenames = load_and_show_data(test_path, num_images=5)

# At this point, `train_images` and `test_images` are ready for further processing,
# such as applying PCA, training a model, etc.
# Out:
# Training Data:
# Testing Data:

# %%
import os
import numpy as np
from keras.preprocessing.image import load_img, img_to_array

# Function to load images and labels from a folder
def load_data(folder_path):
    images = []
    labels = []
    
    for filename in os.listdir(folder_path):
        if filename.lower().endswith('.png'):  # Ensure only PNG files are processed
            img = load_img(os.path.join(folder_path, filename), color_mode='grayscale', target_size=(100, 100))
            images.append(img_to_array(img).flatten())  # Flatten the image
            label = filename.split('_')[0]  # Assuming labels are part of the filename (e.g., 'person1_img1.png')
            labels.append(label)
    
    return np.array(images), np.array(labels)

# Example usage:
train_path = './train/'
test_path = './test/'

# Load train and test datasets
X_train, y_train = load_data(train_path)
X_test, y_test = load_data(test_path)

# %%
from sklearn.preprocessing import StandardScaler

# Function to normalize the data
def normalize_data(X_train, X_test):
    scaler = StandardScaler()  # Create a StandardScaler instance
    X_train_scaled = scaler.fit_transform(X_train)  # Fit on training data and transform it
    X_test_scaled = scaler.transform(X_test)  # Only transform the test data
    
    return X_train_scaled, X_test_scaled

# Load the data
train_path = './train/'
test_path = './test/'

X_train, y_train = load_data(train_path)
X_test, y_test = load_data(test_path)

# Normalize the train and test data
X_train_normalized, X_test_normalized = normalize_data(X_train, X_test)

# Now `X_train_normalized` and `X_test_normalized` are normalized and ready for further processing

# %%
import numpy as np

# Step 1: Define a function to compute the mean face
def compute_mean_face(images):
    # Convert images list into a numpy array if it's not already
    images_array = np.array(images)
    
    # Compute the mean of the images along the first axis (average pixel-wise)
    mean_face = np.mean(images_array, axis=0)
    
    return mean_face

# %%
# Assuming X_train contains the flattened images
mean_face = compute_mean_face(X_train_normalized)  # Use normalized images for better visualization

# %%
import matplotlib.pyplot as plt

# Step 3: Display the mean face in a plot
def show_mean_face(mean_face, image_shape=(100, 100)):
    # Reshape the mean face back to 100x100
    mean_face_image = mean_face.reshape(image_shape)
    
    # Plot the mean face
    plt.imshow(mean_face_image, cmap='gray')
    plt.title('Mean Face')
    plt.axis('off')
    plt.show()

# Call the function to display the mean face
show_mean_face(mean_face)

# %%
from sklearn.preprocessing import StandardScaler

# Load and preprocess the images
def load_and_preprocess_data(folder_path):
    # Load the images and labels
    images, labels = load_data(folder_path)
    
    # Normalize the images using StandardScaler
    scaler = StandardScaler()
    images_normalized = scaler.fit_transform(images)  # Fit and transform
    
    return images_normalized, labels

# %%
# Subtract the mean face from each image
def subtract_mean_face(images, mean_face):
    images_centered = images - mean_face  # Subtract mean face from each image
    return images_centered

# %%
# Step 4: Putting everything together

# Load, preprocess data, and compute the mean face
train_path = './train/'
test_path = './test/'

# Load and preprocess training data
X_train_normalized, y_train = load_and_preprocess_data(train_path)

# Compute the mean face from the training data
mean_face = compute_mean_face(X_train_normalized)

# Subtract the mean face from each image
X_train_centered = subtract_mean_face(X_train_normalized, mean_face)

# Visualize the mean face
show_mean_face(mean_face)

# Load and preprocess test data
X_test_normalized, y_test = load_and_preprocess_data(test_path)

# Subtract the mean face from the test images
X_test_centered = subtract_mean_face(X_test_normalized, mean_face)

# %%
centered_and_normalized_faces = np.random.rand(100, 64, 64)  # par exemple, 100 images de 64x64

# Maintenant, vous pouvez accéder à sa forme
print(centered_and_normalized_faces.shape)
# Out:
# (100, 64, 64)

# %%
from sklearn.decomposition import PCA

# Apply PCA to the training data (centered data)
def apply_pca(X_train_centered, n_components=42):
    pca = PCA(n_components=n_components)  # You can adjust the number of components
    X_train_pca = pca.fit_transform(X_train_centered)  # Fit PCA on the centered training data
    return pca, X_train_pca

# %%
# Visualize the Eigenfaces (principal components)
def plot_eigenfaces(pca, image_shape=(100, 100), num_eigenfaces=10):
    plt.figure(figsize=(15, 5))
    for i in range(num_eigenfaces):
        plt.subplot(2, 5, i + 1)
        eigenface = pca.components_[i].reshape(image_shape)  # Reshape each principal component to image dimensions
        plt.imshow(eigenface, cmap='gray')
        plt.title(f"Eigenface {i + 1}")
        plt.axis('off')
    plt.show()

# %%
# Project images onto the PCA space (for both train and test sets)
def project_onto_pca(pca, X_centered):
    return pca.transform(X_centered)  # Transform centered data into PCA space

# %%
# Display the first 20 Eigenfaces in a 4x5 grid
def plot_first_20_eigenfaces(pca, image_shape=(100, 100)):
    plt.figure(figsize=(15, 10))  # Create a large figure to display 20 images
    for i in range(20):
        plt.subplot(4, 5, i + 1)  # Create a 4x5 grid of subplots
        eigenface = pca.components_[i].reshape(image_shape)  # Reshape each eigenface
        plt.imshow(eigenface, cmap='gray')
        plt.title(f"Eigenface {i + 1}")
        plt.axis('off')
    plt.tight_layout()  # Adjust layout to prevent overlap
    plt.show()

# Paths to your train folder
train_path = './train/'

# Load and preprocess training data
X_train_normalized, y_train = load_and_preprocess_data(train_path)

# Compute the mean face from the training data
mean_face = np.mean(X_train_normalized, axis=0)

# Subtract the mean face from the training data
X_train_centered = X_train_normalized - mean_face

# Apply PCA on the centered training data
pca, X_train_pca = apply_pca(X_train_centered, n_components=42)

# Visualize the first 20 Eigenfaces
plot_first_20_eigenfaces(pca, image_shape=(100, 100))

# %%
import os

# Function to extract class labels from filenames (if filenames encode class info)
def extract_label_from_filename(filename):
    # Extract label from filename, assuming it's the first part of the filename, like 'personID_imgX.png'
    try:
        # For filenames like 'person1_image1.png', the label could be 'person1'
        return filename.split('_')[0]  # Modify this if your filenames follow a different pattern
    except IndexError:
        return None

# Function to extract class labels from filenames
def extract_label_from_filename(filename):
    # Extract the numeric part after 'IMG_' in the filename, e.g., 'IMG_2404.png' -> '2404'
    try:
        # Split the filename by '_' and take the second part (numeric part)
        return filename.split('_')[1].split('.')[0]  # This will return the numeric part as a string
    except IndexError:
        return None

# Function to load filenames and extract labels based on the filename
def load_filenames_and_labels(images_dir):
    # Get a list of image filenames (filtering by image file extensions)
    image_filenames = [f for f in os.listdir(images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    # Extract labels from the filenames
    labels = [extract_label_from_filename(f) for f in image_filenames]

    # Return the filenames and corresponding labels
    return image_filenames, labels

# Paths to the train and test directories
train_dir = r'C:\Users\HOME\dacpvsrn\train'
test_dir = r'C:\Users\HOME\dacpvsrn\test'

# Load image filenames and labels for train and test directories
train_filenames, train_labels = load_filenames_and_labels(train_dir)
test_filenames, test_labels = load_filenames_and_labels(test_dir)

# Output the results
print("Train Filenames:", train_filenames)
print("Train Labels:", train_labels)
print("Test Filenames:", test_filenames)
print("Test Labels:", test_labels)
# Out:
# Train Filenames: ['IMG_2404.png', 'IMG_2405.png', 'IMG_2406.png', 'IMG_2407.png', 'IMG_2408.png', 'IMG_2409.png', 'IMG_2410.png', 'IMG_2411.png', 'IMG_2412.png', 'IMG_2413.png', 'IMG_2415.png', 'IMG_2416.png', 'IMG_2417.png', 'IMG_2418.png', 'IMG_2419.png', 'IMG_2420.png', 'IMG_2421.png', 'IMG_2422.png', 'IMG_2423.png', 'IMG_2424.png', 'IMG_2426.png', 'IMG_2427.png', 'IMG_2430.png', 'IMG_2434.png', 'IMG_2435.png', 'IMG_2436.png', 'IMG_2437.png', 'IMG_2438.png', 'IMG_2440.png', 'IMG_2442.png', 'IMG_2443.png', 'IMG_2445.png', 'IMG_2446 2.png', 'IMG_2448.png', 'IMG_2449.png', 'IMG_2450.png', 'IMG_2451.png', 'IMG_2452.png', 'IMG_2453.png', 'IMG_2454.png', 'IMG_2455.png', 'IMG_2456.png', 'IMG_2457.png', 'IMG_2458.png', 'IMG_2459.png', 'IMG_2461.png', 'IMG_2462.png', 'IMG_2465.png', 'IMG_2466.png', 'IMG_2467.png', 'IMG_2468.png', 'IMG_2469.png', 'IMG_2470.png', 'IMG_2471.png', 'IMG_2473.png', 'IMG_2474.png', 'IMG_2476.png', 'IMG_2477.png', 'IMG_2478.png', 'IMG_2479.png', 'IMG_2480.png', 'IMG_2481.png', 'IMG_2482.png', 'IMG_2483.png', 'IMG_2484.png', 'IMG_2485.png', 'IMG_2486.png', 'IMG_2487.png', 'IMG_2489.png', 'IMG_2492.png', 'IMG_2493.png', 'IMG_2494.png', 'IMG_2495.png', 'IMG_2496.png', 'IMG_2497.png', 'IMG_2498.png', 'IMG_2500.png', 'IMG_2501.png', 'IMG_2502.png', 'IMG_2503.png', 'IMG_2504.png', 'IMG_2505.png', 'IMG_2507.png', 'IMG_2509.png', 'IMG_2512.png', 'IMG_2513.png', 'IMG_2514.png', 'IMG_2515.png', 'IMG_2517.png', 'IMG_2518.png', 'IMG_2519.png', 'IMG_2520.png', 'IMG_2522.png', 'IMG_2523.png', 'IMG_2524.png', 'IMG_2525.png', 'IMG_2526.png', 'IMG_2527.png', 'IMG_2528.png', 'IMG_2529.png', 'IMG_2530.png', 'IMG_2531.png', 'IMG_2532.png', 'IMG_2533.png', 'IMG_2534.png', 'IMG_2535.png', 'IMG_2536.png', 'IMG_2537.png', 'IMG_2538.png', 'IMG_2540.png', 'IMG_2542.png', 'IMG_2543.png', 'IMG_2544.png', 'IMG_2545.png', 'IMG_2546.png', 'IMG_2547.png', 'IMG_2550.png', 'IMG_2568.png', 'IMG_2571.png', 'IMG_2573.png']
# Train Labels: ['2404', '2405', '2406', '2407', '2408', '2409', '2410', '2411', '2412', '2413', '2415', '2416', '2417', '2418', '2419', '2420', '2421', '2422', '2423', '2424', '2426', '2427', '2430', '2434', '2435', '2436', '2437', '2438', '2440', '2442', '2443', '2445', '2446 2', '2448', '2449', '2450', '2451', '2452', '2453', '2454', '2455', '2456', '2457', '2458', '2459', '2461', '2462', '2465', '2466', '2467', '2468', '2469', '2470', '2471', '2473', '2474', '2476', '2477', '2478', '2479', '2480', '2481', '2482', '2483', '2484', '2485', '2486', '2487', '2489', '2492', '2493', '2494', '2495', '2496', '2497', '2498', '2500', '2501', '2502', '2503', '2504', '2505', '2507', '2509', '2512', '2513', '2514', '2515', '2517', '2518', '2519', '2520', '2522', '2523', '2524', '2525', '2526', '2527', '2528', '2529', '2530', '2531', '2532', '2533', '2534', '2535', '2536', '2537', '2538', '2540', '2542', '2543', '2544', '2545', '2546', '2547', '2550', '2568', '2571', '2573']
# Test Filenames: ['IMG_2414.jpg', 'IMG_2414.png', 'IMG_2425.jpg', 'IMG_2425.png', 'IMG_2428.jpg', 'IMG_2428.png', 'IMG_2429.jpg', 'IMG_2429.png', 'IMG_2431.jpg', 'IMG_2431.png', 'IMG_2432.jpg', 'IMG_2432.png', 'IMG_2433.jpg', 'IMG_2433.png', 'IMG_2439.jpg', 'IMG_2439.png', 'IMG_2441.jpg', 'IMG_2441.png', 'IMG_2444.jpg', 'IMG_2444.png', 'IMG_2447.jpg', 'IMG_2447.png', 'IMG_2460.jpg', 'IMG_2460.png', 'IMG_2464.jpg', 'IMG_2464.png', 'IMG_2472.jpg', 'IMG_2472.png', 'IMG_2475.jpg', 'IMG_2475.png', 'IMG_2488.jpg', 'IMG_2488.png', 'IMG_2490.jpg', 'IMG_2490.png', 'IMG_2491.jpg', 'IMG_2491.png', 'IMG_2499.jpg', 'IMG_2499.png', 'IMG_2506.jpg', 'IMG_2506.png', 'IMG_2508.jpg', 'IMG_2508.png', 'IMG_2510.jpg', 'IMG_2510.png', 'IMG_2511.jpg', 'IMG_2511.png', 'IMG_2516.jpg', 'IMG_2516.png', 'IMG_2521.jpg', 'IMG_2521.png', 'IMG_2539.jpg', 'IMG_2539.png', 'IMG_2541.jpg', 'IMG_2541.png', 'IMG_2548.jpg', 'IMG_2548.png', 'IMG_2549.jpg', 'IMG_2549.png', 'IMG_2569.jpg', 'IMG_2569.png', 'IMG_2570.jpg', 'IMG_2570.png', 'IMG_2572.jpg', 'IMG_2572.png']
# Test Labels: ['2414', '2414', '2425', '2425', '2428', '2428', '2429', '2429', '2431', '2431', '2432', '2432', '2433', '2433', '2439', '2439', '2441', '2441', '2444', '2444', '2447', '2447', '2460', '2460', '2464', '2464', '2472', '2472', '2475', '2475', '2488', '2488', '2490', '2490', '2491', '2491', '2499', '2499', '2506', '2506', '2508', '2508', '2510', '2510', '2511', '2511', '2516', '2516', '2521', '2521', '2539', '2539', '2541', '2541', '2548', '2548', '2549', '2549', '2569', '2569', '2570', '2570', '2572', '2572']

# %%
import os
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from keras.preprocessing.image import load_img, img_to_array

# Function to process images
def process_image(image_path, target_size=(100, 100)):
    img = load_img(image_path, target_size=target_size, color_mode='grayscale')
    img_array = img_to_array(img).flatten()
    return img_array

# Function to load and preprocess images from a directory
def load_and_preprocess_images(image_folder):
    image_filenames = [f for f in os.listdir(image_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    X_images = np.array([process_image(os.path.join(image_folder, f)) for f in image_filenames])
    return X_images, image_filenames

# Paths to the train and test directories
train_dir = r'C:\Users\HOME\dacpvsrn\train'
test_dir = r'C:\Users\HOME\dacpvsrn\test'

# Load and preprocess your training data
X_train, train_labels = load_and_preprocess_images(train_dir)

# Normalize and apply PCA to the training data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  # Fit and transform training data
mean_face = np.mean(X_train_scaled, axis=0)
X_train_centered = X_train_scaled - mean_face
pca = PCA(n_components=42)  # Choose the number of components based on your requirement
X_train_pca = pca.fit_transform(X_train_centered)

# Load and preprocess your test data
X_test, y_test = load_and_preprocess_images(test_dir)

# Normalize the test data using the fitted scaler
X_test_scaled = scaler.transform(X_test)

# Center the test data by subtracting the mean face
X_test_centered = X_test_scaled - mean_face

# Apply PCA on the test data
X_test_pca = pca.transform(X_test_centered)  # Use the PCA model fitted on the training data

# Now, calculate predicted labels for the test data
y_pred_pca = []

for i in range(X_test_pca.shape[0]):
    # Calculate distances between the test image and all training images
    distances = np.linalg.norm(X_train_pca - X_test_pca[i], axis=1)
    # Find the index of the closest training image
    recognized_face_index = np.argmin(distances)
    # Get the corresponding label of the closest training image
    recognized_face_label = train_labels[recognized_face_index]
    y_pred_pca.append(recognized_face_label)

print("Predicted Labels for Test Data:", y_pred_pca)
# Out:
# Predicted Labels for Test Data: ['IMG_2421.png', 'IMG_2421.png', 'IMG_2426.png', 'IMG_2426.png', 'IMG_2427.png', 'IMG_2427.png', 'IMG_2427.png', 'IMG_2427.png', 'IMG_2430.png', 'IMG_2430.png', 'IMG_2501.png', 'IMG_2501.png', 'IMG_2427.png', 'IMG_2427.png', 'IMG_2440.png', 'IMG_2440.png', 'IMG_2440.png', 'IMG_2440.png', 'IMG_2453.png', 'IMG_2453.png', 'IMG_2454.png', 'IMG_2454.png', 'IMG_2459.png', 'IMG_2459.png', 'IMG_2467.png', 'IMG_2467.png', 'IMG_2471.png', 'IMG_2471.png', 'IMG_2477.png', 'IMG_2477.png', 'IMG_2489.png', 'IMG_2489.png', 'IMG_2496.png', 'IMG_2496.png', 'IMG_2492.png', 'IMG_2492.png', 'IMG_2505.png', 'IMG_2505.png', 'IMG_2505.png', 'IMG_2505.png', 'IMG_2502.png', 'IMG_2502.png', 'IMG_2509.png', 'IMG_2509.png', 'IMG_2513.png', 'IMG_2513.png', 'IMG_2517.png', 'IMG_2517.png', 'IMG_2525.png', 'IMG_2525.png', 'IMG_2536.png', 'IMG_2536.png', 'IMG_2492.png', 'IMG_2492.png', 'IMG_2547.png', 'IMG_2547.png', 'IMG_2550.png', 'IMG_2550.png', 'IMG_2568.png', 'IMG_2568.png', 'IMG_2573.png', 'IMG_2573.png', 'IMG_2573.png', 'IMG_2573.png']

# %%
import os

train_dir = 'C:\\Users\\HOME\\dacpvsrn\\train'
if os.path.exists(train_dir):
    files_in_directory = os.listdir(train_dir)
    print(f"Fichiers dans le répertoire {train_dir}:")
    print(files_in_directory)
else:
    print(f"Le répertoire {train_dir} n'existe pas.")
# Out:
# Fichiers dans le répertoire C:\Users\HOME\dacpvsrn\train:
# ['.ipynb_checkpoints', 'IMG_2404.HEIC', 'IMG_2404.png', 'IMG_2405.HEIC', 'IMG_2405.png', 'IMG_2406.HEIC', 'IMG_2406.png', 'IMG_2407.HEIC', 'IMG_2407.png', 'IMG_2408.HEIC', 'IMG_2408.png', 'IMG_2409.HEIC', 'IMG_2409.png', 'IMG_2410.HEIC', 'IMG_2410.png', 'IMG_2411.HEIC', 'IMG_2411.png', 'IMG_2412.HEIC', 'IMG_2412.png', 'IMG_2413.HEIC', 'IMG_2413.png', 'IMG_2415.HEIC', 'IMG_2415.png', 'IMG_2416.HEIC', 'IMG_2416.png', 'IMG_2417.HEIC', 'IMG_2417.png', 'IMG_2418.HEIC', 'IMG_2418.png', 'IMG_2419.HEIC', 'IMG_2419.png', 'IMG_2420.HEIC', 'IMG_2420.png', 'IMG_2421.HEIC', 'IMG_2421.png', 'IMG_2422.HEIC', 'IMG_2422.png', 'IMG_2423.HEIC', 'IMG_2423.png', 'IMG_2424.HEIC', 'IMG_2424.png', 'IMG_2426.HEIC', 'IMG_2426.png', 'IMG_2427.HEIC', 'IMG_2427.png', 'IMG_2430.HEIC', 'IMG_2430.png', 'IMG_2434.HEIC', 'IMG_2434.png', 'IMG_2435.HEIC', 'IMG_2435.png', 'IMG_2436.HEIC', 'IMG_2436.png', 'IMG_2437.HEIC', 'IMG_2437.png', 'IMG_2438.HEIC', 'IMG_2438.png', 'IMG_2440.HEIC', 'IMG_2440.png', 'IMG_2442.HEIC', 'IMG_2442.png', 'IMG_2443.HEIC', 'IMG_2443.png', 'IMG_2445.HEIC', 'IMG_2445.png', 'IMG_2446 2.HEIC', 'IMG_2446 2.png', 'IMG_2448.HEIC', 'IMG_2448.png', 'IMG_2449.HEIC', 'IMG_2449.png', 'IMG_2450.HEIC', 'IMG_2450.png', 'IMG_2451.HEIC', 'IMG_2451.png', 'IMG_2452.HEIC', 'IMG_2452.png', 'IMG_2453.HEIC', 'IMG_2453.png', 'IMG_2454.HEIC', 'IMG_2454.png', 'IMG_2455.HEIC', 'IMG_2455.png', 'IMG_2456.HEIC', 'IMG_2456.png', 'IMG_2457.HEIC', 'IMG_2457.png', 'IMG_2458.HEIC', 'IMG_2458.png', 'IMG_2459.HEIC', 'IMG_2459.png', 'IMG_2461.HEIC', 'IMG_2461.png', 'IMG_2462.HEIC', 'IMG_2462.png', 'IMG_2465.HEIC', 'IMG_2465.png', 'IMG_2466.HEIC', 'IMG_2466.png', 'IMG_2467.HEIC', 'IMG_2467.png', 'IMG_2468.HEIC', 'IMG_2468.png', 'IMG_2469.HEIC', 'IMG_2469.png', 'IMG_2470.HEIC', 'IMG_2470.png', 'IMG_2471.HEIC', 'IMG_2471.png', 'IMG_2473.HEIC', 'IMG_2473.png', 'IMG_2474.HEIC', 'IMG_2474.png', 'IMG_2476.HEIC', 'IMG_2476.png', 'IMG_2477.HEIC', 'IMG_2477.png', 'IMG_2478.HEIC', 'IMG_2478.png', 'IMG_2479.HEIC', 'IMG_2479.png', 'IMG_2480.HEIC', 'IMG_2480.png', 'IMG_2481.HEIC', 'IMG_2481.png', 'IMG_2482.HEIC', 'IMG_2482.png', 'IMG_2483.HEIC', 'IMG_2483.png', 'IMG_2484.HEIC', 'IMG_2484.png', 'IMG_2485.HEIC', 'IMG_2485.png', 'IMG_2486.HEIC', 'IMG_2486.png', 'IMG_2487.HEIC', 'IMG_2487.png', 'IMG_2489.HEIC', 'IMG_2489.png', 'IMG_2492.HEIC', 'IMG_2492.png', 'IMG_2493.HEIC', 'IMG_2493.png', 'IMG_2494.HEIC', 'IMG_2494.png', 'IMG_2495.HEIC', 'IMG_2495.png', 'IMG_2496.HEIC', 'IMG_2496.png', 'IMG_2497.HEIC', 'IMG_2497.png', 'IMG_2498.HEIC', 'IMG_2498.png', 'IMG_2500.HEIC', 'IMG_2500.png', 'IMG_2501.HEIC', 'IMG_2501.png', 'IMG_2502.HEIC', 'IMG_2502.png', 'IMG_2503.HEIC', 'IMG_2503.png', 'IMG_2504.HEIC', 'IMG_2504.png', 'IMG_2505.HEIC', 'IMG_2505.png', 'IMG_2507.HEIC', 'IMG_2507.png', 'IMG_2509.HEIC', 'IMG_2509.png', 'IMG_2512.HEIC', 'IMG_2512.png', 'IMG_2513.HEIC', 'IMG_2513.png', 'IMG_2514.HEIC', 'IMG_2514.png', 'IMG_2515.HEIC', 'IMG_2515.png', 'IMG_2517.HEIC', 'IMG_2517.png', 'IMG_2518.HEIC', 'IMG_2518.png', 'IMG_2519.HEIC', 'IMG_2519.png', 'IMG_2520.HEIC', 'IMG_2520.png', 'IMG_2522.HEIC', 'IMG_2522.png', 'IMG_2523.HEIC', 'IMG_2523.png', 'IMG_2524.HEIC', 'IMG_2524.png', 'IMG_2525.HEIC', 'IMG_2525.png', 'IMG_2526.HEIC', 'IMG_2526.png', 'IMG_2527.HEIC', 'IMG_2527.png', 'IMG_2528.HEIC', 'IMG_2528.png', 'IMG_2529.HEIC', 'IMG_2529.png', 'IMG_2530.HEIC', 'IMG_2530.png', 'IMG_2531.HEIC', 'IMG_2531.png', 'IMG_2532.HEIC', 'IMG_2532.png', 'IMG_2533.HEIC', 'IMG_2533.png', 'IMG_2534.HEIC', 'IMG_2534.png', 'IMG_2535.HEIC', 'IMG_2535.png', 'IMG_2536.HEIC', 'IMG_2536.png', 'IMG_2537.HEIC', 'IMG_2537.png', 'IMG_2538.HEIC', 'IMG_2538.png', 'IMG_2540.HEIC', 'IMG_2540.png', 'IMG_2542.HEIC', 'IMG_2542.png', 'IMG_2543.HEIC', 'IMG_2543.png', 'IMG_2544.HEIC', 'IMG_2544.png', 'IMG_2545.HEIC', 'IMG_2545.png', 'IMG_2546.HEIC', 'IMG_2546.png', 'IMG_2547.HEIC', 'IMG_2547.png', 'IMG_2550.HEIC', 'IMG_2550.png', 'IMG_2568.HEIC', 'IMG_2568.png', 'IMG_2571.HEIC', 'IMG_2571.png', 'IMG_2573.HEIC', 'IMG_2573.png', 'Untitled.ipy ...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

def calculate_accuracy_and_score(y_true, y_pred):
    """
    Calcule l'accuracy et la matrice de confusion, et affiche les résultats.
    
    y_true : les étiquettes réelles
    y_pred : les étiquettes prédites
    """
    # Calcul de l'accuracy
    accuracy = accuracy_score(y_true, y_pred) * 100  # Convertir en pourcentage

    # Calcul de la matrice de confusion
    conf_matrix = confusion_matrix(y_true, y_pred)
    
    # Affichage des résultats
    print(f"Accuracy: {accuracy:.2f}%")
    print("Confusion Matrix:")
    print(conf_matrix)
    
    return accuracy, conf_matrix

# Exemple d'utilisation
# Supposons que y_test sont les vraies étiquettes et y_pred_pca sont les prédictions

# EXEMPLE: Vous devez remplacer ces listes par vos données réelles
y_test = [1, 0, 1, 1, 0, 1, 0]  # Vraies étiquettes (exemple)
y_pred_pca = [1, 0, 1, 0, 0, 1, 1]  # Prédictions (exemple)

# Appel de la fonction
accuracy, conf_matrix = calculate_accuracy_and_score(y_test, y_pred_pca)
# Out:
# Accuracy: 71.43%
# Confusion Matrix:
# [[2 1]
#  [1 3]]

# %%
import numpy as np
from sklearn.metrics import accuracy_score

# Assuming y_test and y_pred_pca are already defined
# y_test: true labels for the test dataset
# y_pred_pca: predicted labels from your model

# Calculate accuracy of the predictions
accuracy = accuracy_score(y_test, y_pred_pca)

# Print accuracy as a percentage
print(f"Accuracy: {accuracy * 100:.2f}%")  # Multiply by 100 to convert to percentage

# Function to calculate recognition score
def calculate_recognition_score(true_labels, predicted_labels):
    correct_predictions = sum(np.array(true_labels) == np.array(predicted_labels))
    total_predictions = len(true_labels)
    recognition_score = (correct_predictions / total_predictions) * 100
    return recognition_score

# Calculate and print the recognition score
recognition_score = calculate_recognition_score(y_test, y_pred_pca)
print(f"Recognition Score: {recognition_score:.2f}%")
# Out:
# Accuracy: 71.43%
# Recognition Score: 71.43%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming y_test and y_pred_pca are already defined
# y_test: true labels for the test dataset
# y_pred_pca: predicted labels from your model

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred_pca)

# Set up the matplotlib figure
plt.figure(figsize=(10, 7))
sns.set(font_scale=1.4)  # Increase font size for readability

# Create the heatmap with integer labels
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=np.arange(cm.shape[1]),  # Use integers for the x-axis labels
            yticklabels=np.arange(cm.shape[0]),  # Use integers for the y-axis labels
            cbar_kws={'label': 'Number of Predictions'})

# Customize labels and title
plt.title('Confusion Matrix with PCA', fontsize=16)
plt.xlabel('Predicted Labels', fontsize=14)
plt.ylabel('Actual Labels', fontsize=14)

# Show the plot
plt.show()
